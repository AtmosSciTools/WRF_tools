# %%
import pandas as pd
import os

dataset = 'GHCNh'
station_file = os.path.join(f"../../../data/point_data/{dataset}", "summaries", "stations_summary.csv")
station_file = '../data/point_data/GHCNh/summaries/stations_summary.csv'
station_file = 'wrf_tools/data/ghcnh-station-list.csv'
station_df = pd.read_csv(station_file)
station_df
# Out:
#            GHCN_ID  LATITUDE  LONGITUDE  ELEVATION STATE  \
# 0      AAI0000TNCA   12.5014   -70.0152       18.3   NaN
# 1      ACL000BARA9   17.5910   -61.8210        5.0    TX
# 2      ACM00078861   17.1167   -61.7833       10.0   NaN
# 3      ACU55-00189   18.6000   -63.4700       10.0   NaN
# 4      ACU55-00190   18.6000   -63.4700       12.0   NaN
# ...            ...       ...        ...        ...   ...
# 34176  ZIM00067967  -21.3833    28.9833      770.0   NaN
# 34177  ZIM00067974  -19.8333    30.7833     -999.9   NaN
# 34178  ZIM00067976  -20.5500    31.0833      700.0   NaN
# 34179  ZIM00067979  -20.3333    31.4667      770.0   NaN
# 34180  ZIM00067989  -20.4170    32.3170      442.0   NaN
#
#                                  NAME  GSN (US)HCN_(US)CRN WMO_ID ICAO
# 0                  REINA BEATRIX INTL  NaN             NaN    NaN  NaN
# 1                             BARBUDA  NaN             NaN    NaN  NaN
# ...

# %%
pd.set_option("display.max_columns", None) 
df = pd.read_csv('../data/point_data/GHCNh/GHCNh_THI0000VTBD_2025.psv', index_col=2, parse_dates=True, sep="|")

df
# Out:
# /tmp/ipykernel_450305/4291884568.py:2: DtypeWarning: Columns (49,51,53,72,73,75,77,211,213,215) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/point_data/GHCNh/GHCNh_THI0000VTBD_2025.psv', index_col=2, parse_dates=True, sep="|")
#                          STATION  Station_name  LATITUDE  LONGITUDE  \
# DATE
# 2025-01-01 00:00:00  THI0000VTBD  BANGKOK INTL   13.9126   100.6068
# 2025-01-01 00:30:00  THI0000VTBD  BANGKOK INTL   13.9126   100.6068
# 2025-01-01 01:00:00  THI0000VTBD  BANGKOK INTL   13.9126   100.6068
# 2025-01-01 01:30:00  THI0000VTBD  BANGKOK INTL   13.9126   100.6068
# 2025-01-01 02:00:00  THI0000VTBD  BANGKOK INTL   13.9126   100.6068
# ...                          ...           ...       ...        ...
# 2025-04-03 19:30:00  THI0000VTBD  BANGKOK INTL   13.9126   100.6068
# 2025-04-03 20:00:00  THI0000VTBD  BANGKOK INTL   13.9126   100.6068
# 2025-04-03 20:30:00  THI0000VTBD  BANGKOK INTL   13.9126   100.6068
# ...
